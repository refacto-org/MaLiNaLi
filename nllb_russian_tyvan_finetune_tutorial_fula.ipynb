# %% [markdown]
# In this notebook, I show how to fine-tune a NLLB-200 machine translation model for a new language.
#
# The new language will be [Tyvan](https://en.wikipedia.org/wiki/Tuvan_language), and I will use a Tyvan-Russian parallel corpus as the training data.
#
# I am running this notebook on Google Colab with a T4 GPU that has 15Gb of memory. If you run it elsewhere, you may want to adjust the batch size, so that there are no OOM errors, but the GPU is well utilized.

# %% [markdown]
# # 0. Preliminaries

# %% [markdown]
# I run this notebook in Google Colab (which is ephemeral), and to read the dataset and to write the resulting model I use Google Drive, which I mount in the cell below.

# %%
from google.colab import drive
import os
if not os.path.exists('/gd'):
    drive.mount('/gd')
# Out:
# Mounted at /gd

# %% [markdown]
# Installing dependencies:
# * `transformers`, as a neural network framework
# * `sentencepiece`, a backend for my tokenizer (the algorithm for converting a text into symbols from the model's vocabulary)
# * `sacremoses`, a package required for text preprocessing with which NLLB models were pretrained.
# * `sacrebleu`, a package for evaluating translation models

# %%
import locale
def gpe(x=None):
    return "UTF-8"
locale.getpreferredencoding = gpe

# %%
# !pip install sentencepiece transformers==4.33 datasets sacremoses sacrebleu  -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 49.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 47.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 68.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.5 MB/s eta 0:00:00

# %% [markdown]
# # 1. Exploring the data
#
# In this section, I try to understand what is the training data that I have, and how suitable it is for fine-tuning a NLLB model.

# %%
import pandas as pd

# %%
trans_df = pd.read_csv('/gd/MyDrive/fra_fuf_all.tsv', sep="\t")
print(trans_df.shape)
print(trans_df.columns)
# Out:
# (20322, 3)
# Index(['fra', 'fuf', 'split'], dtype='object')

# %%
pd.options.display.max_colwidth = 100

# %%
trans_df.sample(10)
# Out:
#                                                                                                        fra  \
# 10879            Lorsqu'il nous rencontra à Assos , nous le prîmes à bord , et nous arrivâmes à Mitylène .
# 18724                                                                                               réunir
# 19929                                                                                    Gâter un enfant .
# 7397   Comme il était assis sur le siège du jugement , sa femme lui envoya dire : « Ne te mêle pas de c...
# 14900                                                                                           aspiration
# 8561   Mais il leur dit : « Vous leur donnez à manger . » Ils dirent : « Nous n'avons pas plus de cinq ...
# 7835   Le sel est bon , mais si le sel a perdu sa saveur , avec quoi l'assaisonnerez-vous ? Ayez du sel...
# 11441  Mais , dis-je , n'ont-ils pas entendu ? Oui , très certainement , « Leur son s'est répandu dans ...
# 16217                                                                                              échange
# 662    Et à vous la moitié de ce que laissent vos épouses, si elles n'ont pas d'enfants. Si elles ont u...
#
#                                                                                                        fuf  \
# 10879  Ɗon kisan , o ƴetti suufaaɓe e yeesooɓe mun , ɓe wubbani ɓen eɓɓunooɓe warugol Puulusa . No ɓe y...
# 18724                                                                                             hiraango
# 19929                                                               si a yennii lan mi ɓoɓete hunnduko kon
# 7397   Onsay Iisaa ari fotti e maɓɓe , o wi'i ɓe : « Mi salminii on ! » Onsay ɓe ɓadii , ɓe nangi koyɗe...
# 14900                                                                                                jakka
# 8561   Tabitee e ndun suudu ɗon , ɲaamon yaron ko ɓe okkori on ɗon woo , ko fii golloowo no handi e njo...
# 7835           Onsay ɓe yahi , ɓe tawi mbabun no humii ka yaasi e binde dambugal ka ɗatal , ɓe hunti kun .
# 11441                    Wota on yoɓitir gooto bone bone . Waɗee ko yimɓe ɓen fow ndaarata tawa no moƴƴi .
# 16217                                                                                             majjunde
# 662    Hino woodani on feccere e ko rewɓe mon acci, si tawii ɓe maraa ɓiɗɗo. Si tawii hiɓe mari ɓiɗɗo, ...
#
#        split
# 10879  train
# 18724  train
# 19929  train
# 7397   train
# 14900  train
# 8561   train
# 7835   train
# 11441  train
# 16217  train
# 662    train

# %%
trans_df.isnull().sum()
# Out:
# fra      0
# fuf      0
# split    0
# dtype: int64

# %%
trans_df.split.value_counts()
# Out:
# train    20122
# dev        100
# test       100
# Name: split, dtype: int64

# %%
df_train = trans_df[trans_df.split=='train'].copy() # 49000 items
df_dev = trans_df[trans_df.split=='dev'].copy()     # 500 items
df_test = trans_df[trans_df.split=='test'].copy()   # 500 items

# %% [markdown]
# # 2. How well does the data fit into a NLLB tokenizer?

# %%
from transformers import NllbTokenizer
from tqdm.auto import tqdm, trange

# %%
tokenizer = NllbTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-d39e54aebe7c> in <cell line: 1>()
# ----> 1 tokenizer = NllbTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattribute__(cls, key)
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in requires_backends(obj, backends)
#
# ImportError:
# NllbTokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import re

def word_tokenize(text):
    # a very naive word tokenizer for languages with English-like orthography
    return re.findall('(\w+|[^\w\s])', text)

# %%
smpl = df_train.sample(10000, random_state=1)

smpl['fra_toks'] = smpl.fra.apply(tokenizer.tokenize)
smpl['fuf_toks'] = smpl.fuf.apply(tokenizer.tokenize)

smpl['fra_words'] = smpl.fra.apply(word_tokenize)
smpl['fuf_words'] = smpl.fuf.apply(word_tokenize)

# %%
smpl.sample(5)[['fra', 'fra_words', 'fra_toks', 'fuf', 'fuf_words', 'fuf_toks']]
# Out:
#                                                                                                        fra  \
# 7095   Les disciples , voyant cela , s'étonnèrent et dirent : « Comment le figuier a-t-il pu se desséch...
# 10688  Mais quelques-uns de la secte des pharisiens croyants se levèrent , disant : « Il faut les circo...
# 5009                          Détourne-toi d'eux. Le jour où l'appeleur appellera vers une chose affreuse,
# 4286   Et ceux qui avaient mécru seront conduits par groupes à l'Enfer. Puis, quand ils y parviendront,...
# 4035                                                           Ils lui tournèrent le dos et s'en allèrent.
#
#                                                                                                  fra_words  \
# 7095   [Les, disciples, ,, voyant, cela, ,, s, ', étonnèrent, et, dirent, :, «, Comment, le, figuier, a...
# 10688  [Mais, quelques, -, uns, de, la, secte, des, pharisiens, croyants, se, levèrent, ,, disant, :, «...
# 5009   [Détourne, -, toi, d, ', eux, ., Le, jour, où, l, ', appeleur, appellera, vers, une, chose, affr...
# 4286   [Et, ceux, qui, avaient, mécru, seront, conduits, par, groupes, à, l, ', Enfer, ., Puis, ,, quan...
# 4035                                            [Ils, lui, tournèrent, le, dos, et, s, ', en, allèrent, .]
#
#                                                                                                   fra_toks  \
# 7095   [▁Les, ▁disciples, ▁,, ▁voy, ant, ▁cela, ▁,, ▁s, ', ét, onn, èrent, ▁et, ▁dirent, ▁:, ▁, «, ▁Com...
# 10688  [▁Mais, ▁quelques, -, uns, ▁de, ▁la, ▁sec, te, ▁des, ▁phar, isi, ens, ▁cro, y, ants, ▁se, ▁lev, ...
# 5009   [▁Dé, tour, ne, -, toi, ▁d, ', eux, ., ▁Le, ▁jour, ▁où, ▁l, ', ap, pele, ur, ▁appell, era, ▁vers...
# 4286   [▁Et, ▁ceux, ▁qui, ▁avaient, ▁mé, c, ru, ▁seront, ▁condu, its, ▁par, ▁groupes, ▁à, ▁l, ', En, fe...
# 4035                                [▁Ils, ▁lui, ▁tourn, èrent, ▁le, ▁dos, ▁et, ▁s, ', en, ▁all, èrent, .]
#
#                                                                                                        fuf  \
# 7095   Ko fii ka ummutal , worɓe ɓen resataa , rewɓe ɓen kadi resetaake , kono ɓe wa'ay wa malaa'ikaaɓe...
# 10688     ɓe janna naamuuji ɗi en newnanaaka jaɓugol maa waɗugol , enen ɓee jeyaaɓe e laamateeri Roomu ! »
# 5009                                                                e toolorde goonga, ka Laamɗo Hattanɗo.
# 4286   Mo gollii bone, o yoɓitetaake, si wanaa yeru makko; mo gollii kadi moƴƴere, foti ko gorko maa de...
# 4035                                              Men daɗni ɓe, kamɓe e yimɓe maɓɓe ɓen, e ngoƴo mawnungo,
#
#                                                                                                  fuf_words  \
# 7095   [Ko, fii, ka, ummutal, ,, worɓe, ɓen, resataa, ,, rewɓe, ɓen, kadi, resetaake, ,, kono, ɓe, wa, ...
# 10688  [ɓe, janna, naamuuji, ɗi, en, newnanaaka, jaɓugol, maa, waɗugol, ,, enen, ɓee, jeyaaɓe, e, laama...
# 5009                                                     [e, toolorde, goonga, ,, ka, Laamɗo, Hattanɗo, .]
# 4286   [Mo, gollii, bone, ,, o, yoɓitetaake, ,, si, wanaa, yeru, makko, ;, mo, gollii, kadi, moƴƴere, ,...
# 4035                            [Men, daɗni, ɓe, ,, kamɓe, e, yimɓe, maɓɓe, ɓen, ,, e, ngoƴo, mawnungo, ,]
#
#                                                                                                   fuf_toks
# 7095   [▁Ko, ▁fii, ▁ka, ▁um, mut, al, ▁,, ▁wor, ɓe, ▁ɓen, ▁res, ataa, ▁,, ▁rew, ɓe, ▁ɓen, ▁kadi, ▁res, ...
# 10688  [▁ɓe, ▁jan, na, ▁na, amuu, ji, ▁ɗi, ▁en, ▁ne, wn, ana, aka, ▁ja, ɓ, ugol, ▁maa, ▁waɗ, ugol, ▁,, ...
# 5009                                         [▁e, ▁tool, orde, ▁goonga, ,, ▁ka, ▁Laamɗo, ▁H, attan, ɗo, .]
# 4286   [▁Mo, ▁gol, lii, ▁bone, ,, ▁o, ▁yo, ɓ, it, eta, ake, ,, ▁si, ▁wana, a, ▁y, eru, ▁makko, ;, ▁mo, ...
# 4035     [▁Men, ▁da, ɗ, ni, ▁ɓe, ,, ▁kam, ɓe, ▁e, ▁yimɓe, ▁maɓɓe, ▁ɓen, ,, ▁e, ▁ngo, ƴ, o, ▁mawn, ungo, ,]

# %%
stats = smpl[['fuf_toks', 'fra_toks', 'fuf_words', 'fra_words']].applymap(len).describe()
stats
# Out:
#            fuf_toks     fra_toks     fuf_words     fra_words
# count  10000.000000  10000.00000  10000.000000  10000.000000
# mean      28.931100     26.97300     18.951600     21.885000
# std       25.176138     24.12413     16.988617     19.911866
# min        1.000000      1.00000      1.000000      1.000000
# 25%        4.000000      4.00000      2.000000      2.000000
# 50%       27.000000     25.00000     18.000000     20.000000
# 75%       44.000000     40.00000     29.000000     33.000000
# max      344.000000    382.00000    235.000000    316.000000

# %%
print(stats.fuf_toks['mean'] / stats.fuf_words['mean'])
print(stats.fra_toks['mean'] / stats.fra_words['mean'])
# Out:
# 1.5265782308617744
# 1.2324880054832075

# %%
print(tokenizer.unk_token, tokenizer.unk_token_id)
# Out:
# <unk> 3

# %% [markdown]
# Good news: both for Russian and Tyvan, the NLLB tokenizer seems to produce around 2 tokens per word (more precisely, 2.3 and 1.8), which means that the translation quality of fine-tuned NLLB may be decent even without vocabulary extension.

# %% [markdown]
# One more check: how often does the <unk> token happen in the tokenizer output for Tyvan? If this is too often, we need to fix it somehow

# %%
texts_with_unk = [text for text in tqdm(trans_df.tyv) if tokenizer.unk_token_id in tokenizer(text).input_ids]
print(len(texts_with_unk))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-fa2bc6e0d310> in <cell line: 1>()
# ----> 1 texts_with_unk = [text for text in tqdm(trans_df.tyv) if tokenizer.unk_token_id in tokenizer(text).input_ids]
#       2 print(len(texts_with_unk))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tyv'

# %%
import random
s = random.sample(texts_with_unk, 5)
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-75fbb4454c0b> in <cell line: 2>()
#       1 import random
# ----> 2 s = random.sample(texts_with_unk, 5)
#       3 s
#
# NameError: name 'texts_with_unk' is not defined

# %% [markdown]
# Apparently, most of the texts with 3634 unknown tokens just have some punctuation unfamiliar to the NLLB tokenizer.
#
# This is because the NLLB model was pretrained on normalized texts. If we reproduce the normalization, most of the problems would be fixed.

# %%
# this code is adapted from  the Stopes repo of the NLLB team
# https://github.com/facebookresearch/stopes/blob/main/stopes/pipelines/monolingual/monolingual_line_processor.py#L214

import re
import sys
import typing as tp
import unicodedata
from sacremoses import MosesPunctNormalizer


mpn = MosesPunctNormalizer(lang="en")
mpn.substitutions = [
    (re.compile(r), sub) for r, sub in mpn.substitutions
]


def get_non_printing_char_replacer(replace_by: str = " ") -> tp.Callable[[str], str]:
    non_printable_map = {
        ord(c): replace_by
        for c in (chr(i) for i in range(sys.maxunicode + 1))
        # same as \p{C} in perl
        # see https://www.unicode.org/reports/tr44/#General_Category_Values
        if unicodedata.category(c) in {"C", "Cc", "Cf", "Cs", "Co", "Cn"}
    }

    def replace_non_printing_char(line) -> str:
        return line.translate(non_printable_map)

    return replace_non_printing_char

replace_nonprint = get_non_printing_char_replacer(" ")

def preproc(text):
    clean = mpn.normalize(text)
    clean = replace_nonprint(clean)
    # replace 𝓕𝔯𝔞𝔫𝔠𝔢𝔰𝔠𝔞 by Francesca
    clean = unicodedata.normalize("NFKC", clean)
    return clean

# %%
texts_with_unk_normed = [text for text in tqdm(texts_with_unk) if tokenizer.unk_token_id in tokenizer(preproc(text)).input_ids]
print(len(texts_with_unk_normed))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-47d2394c3ceb> in <cell line: 1>()
# ----> 1 texts_with_unk_normed = [text for text in tqdm(texts_with_unk) if tokenizer.unk_token_id in tokenizer(preproc(text)).input_ids]
#       2 print(len(texts_with_unk_normed))
#
# NameError: name 'texts_with_unk' is not defined

# %% [markdown]
# Indeed, after normalizing texts, none of them contain unknown tokens. We will use this as one more piece of evidence that we don't have to update the tokenizer vocabulary to use it with Tyvan.

# %% [markdown]
# # 3 (optional). Expanding the vocabulary

# %% [markdown]
# # 4. Adding a new language tag to the tokenizer and model

# %%
from transformers import AutoModelForSeq2SeqLM
from transformers import NllbTokenizer

# %%
tokenizer = NllbTokenizer.from_pretrained('facebook/nllb-200-distilled-600M')
print(len(tokenizer))
print(tokenizer.convert_ids_to_tokens([256202, 256203]))
# Out:
# 256204
# ['zul_Latn', '<mask>']

# %%
def fix_tokenizer(tokenizer, new_lang='fuf_Latn'):
    """
    Add a new language token to the tokenizer vocabulary
    (this should be done each time after its initialization)
    """
    old_len = len(tokenizer) - int(new_lang in tokenizer.added_tokens_encoder)
    tokenizer.lang_code_to_id[new_lang] = old_len-1
    tokenizer.id_to_lang_code[old_len-1] = new_lang
    # always move "mask" to the last position
    tokenizer.fairseq_tokens_to_ids["<mask>"] = len(tokenizer.sp_model) + len(tokenizer.lang_code_to_id) + tokenizer.fairseq_offset

    tokenizer.fairseq_tokens_to_ids.update(tokenizer.lang_code_to_id)
    tokenizer.fairseq_ids_to_tokens = {v: k for k, v in tokenizer.fairseq_tokens_to_ids.items()}
    if new_lang not in tokenizer._additional_special_tokens:
        tokenizer._additional_special_tokens.append(new_lang)
    # clear the added token encoder; otherwise a new token may end up there by mistake
    tokenizer.added_tokens_encoder = {}
    tokenizer.added_tokens_decoder = {}

# %%
fix_tokenizer(tokenizer)

# %%
print(tokenizer.convert_ids_to_tokens([256202, 256203, 256204])) # ['zul_Latn', 'tyv_Cyrl', '<mask>']
print(tokenizer.convert_tokens_to_ids(['zul_Latn', 'fuf_Latn', '<mask>'])) # [256202, 256203, 256204]
# this is consistent now, wow!
# Out:
# ['zul_Latn', 'fuf_Latn', '<mask>']
# [256202, 256203, 256204]

# %%
added_token_id = tokenizer.convert_tokens_to_ids('fuf_Latn')
similar_lang_id = tokenizer.convert_tokens_to_ids('fuv_Latn')
print(added_token_id, similar_lang_id)
# Out:
# 256203 256059

# %%
model = AutoModelForSeq2SeqLM.from_pretrained('facebook/nllb-200-distilled-600M')
model.resize_token_embeddings(len(tokenizer))
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 256205. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc
# Embedding(256205, 1024)

# %%
# moving the embedding for "mask" to its new position
model.model.shared.weight.data[added_token_id+1] = model.model.shared.weight.data[added_token_id]
# initializing new language token with a token of a similar language
model.model.shared.weight.data[added_token_id] = model.model.shared.weight.data[similar_lang_id]

# %% [markdown]
# # 5. Preparing the training loop

# %%
import gc
import random
import numpy as np
import torch
from tqdm.auto import tqdm, trange
from transformers.optimization import Adafactor
from transformers import get_constant_schedule_with_warmup

def cleanup():
    """Try to free GPU memory"""
    gc.collect()
    torch.cuda.empty_cache()

cleanup()

# %%
model.cuda();

# %%
optimizer = Adafactor(
    [p for p in model.parameters() if p.requires_grad],
    scale_parameter=False,
    relative_step=False,
    lr=1e-4,
    clip_threshold=1.0,
    weight_decay=1e-3,
)

# %%
batch_size = 16  # 32 already doesn't fit well to 15GB of GPU memory
max_length = 128
warmup_steps = 1_000
training_steps = 57000

# %%
losses = []
scheduler = get_constant_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps)

# %%
LANGS = [('fra', 'fra_Latn'), ('fuf', 'fuf_Latn')]

def get_batch_pairs(batch_size, data=df_train):
    (l1, long1), (l2, long2) = random.sample(LANGS, 2)
    xx, yy = [], []
    for _ in range(batch_size):
        item = data.iloc[random.randint(0, len(data)-1)]
        xx.append(preproc(item[l1]))
        yy.append(preproc(item[l2]))
    return xx, yy, long1, long2

print(get_batch_pairs(1))
# (['чеди'], ['семь'], 'tyv_Cyrl', 'rus_Cyrl')
# Out:
# (['hernie'], ['neɗɗaaku'], 'fra_Latn', 'fuf_Latn')

# %%
MODEL_SAVE_PATH = '/gd/MyDrive/models/nllb-fra-fuf-v1'

# %% [markdown]
# # 6. The training loop

# %%
# If the Colab instance has shut down, you can always load it back from the Google drive where you have saved it
# => if error : Repo id must be in the form 'repo_name' or 'namespace/repo_name':
# might need to rerun most of the above...
from transformers import NllbTokenizer, AutoModelForSeq2SeqLM
model_load_name = '/gd/MyDrive/models/nllb-fra-fuf-v1'
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name).cuda()
tokenizer = NllbTokenizer.from_pretrained(model_load_name)
fix_tokenizer(tokenizer)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model.train()
x, y, loss = None, None, None
cleanup()

tq = trange(len(losses), training_steps)
for i in tq:
    xx, yy, lang1, lang2 = get_batch_pairs(batch_size)
    try:
        tokenizer.src_lang = lang1
        x = tokenizer(xx, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(model.device)
        tokenizer.src_lang = lang2
        y = tokenizer(yy, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(model.device)
        y.input_ids[y.input_ids == tokenizer.pad_token_id] = -100

        loss = model(**x, labels=y.input_ids).loss
        loss.backward()
        losses.append(loss.item())

        optimizer.step()
        optimizer.zero_grad(set_to_none=True)
        scheduler.step()

    except RuntimeError as e:
        optimizer.zero_grad(set_to_none=True)
        x, y, loss = None, None, None
        cleanup()
        print('error', max(len(s) for s in xx + yy), e)
        continue

    if i % 1000 == 0:
        print(i, np.mean(losses[-1000:]))

    if i % 1000 == 0 and i > 0:
        model.save_pretrained(MODEL_SAVE_PATH)
        tokenizer.save_pretrained(MODEL_SAVE_PATH)
# Out:
#   0%|          | 0/57000 [00:00<?, ?it/s]
# 0 3.1950929164886475
# 1000 2.5381391886472704
# 2000 2.454811121582985
# 3000 2.3721364830732345
# 4000 2.2688118087053297
# 5000 2.1960310969352723
# 6000 2.1036984033584596
# 7000 2.040718461871147

# %%
pd.Series(losses).ewm(100).mean().plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-170bb04377cf> in <cell line: 1>()
# ----> 1 pd.Series(losses).ewm(100).mean().plot();
#
# NameError: name 'pd' is not defined

# %%
def translate(text, src_lang='fra_Latn', tgt_lang='fuf_Latn', a=16, b=1.5, max_input_length=1024, **kwargs):
    tokenizer.src_lang = src_lang
    tokenizer.tgt_lang = tgt_lang
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_input_length)
    result = model.generate(
        **inputs.to(model.device),
        forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang),
        max_new_tokens=int(a + b * inputs.input_ids.shape[1]),
        **kwargs
    )
    #print(inputs.input_ids.shape[1], result.shape[1])
    return tokenizer.batch_decode(result, skip_special_tokens=True)

# %%
xx, yy, lang1, lang2 = get_batch_pairs(1, data=df_dev)
print(xx)
print(yy)
model.eval()
print(translate(xx[0], lang1, lang2, no_repeat_ngram_size=3, num_beams=5))
# Out:
# ['Mbela a anndaa wonde ko Alla jeyi laamu asamaanji e lesdi on ngalaa keedanoowo mon wolla ballo sonaa Alla.']
# ["Ne sais-tu pas qu'à Allah, appartient le royaume des cieux et de la terre, et qu'en dehors d'Allah vous n'avez ni protecteur ni secoureur?"]
# ["Ne savez-vous pas qu'Allah a la royauté des cieux et de la terre, et qu'aucun protecteur ne vous est donné en dehors d'Allah?"]

# %%
# !ls -alsh $MODEL_SAVE_PATH
# Out:
# total 2.3G
# 1.0K -rw------- 1 root root  898 Jan 18 00:07 config.json
#  512 -rw------- 1 root root  184 Jan 18 00:07 generation_config.json
# 2.3G -rw------- 1 root root 2.3G Jan 18 00:07 pytorch_model.bin
# 4.7M -rw------- 1 root root 4.7M Jan 14 15:10 sentencepiece.bpe.model
# 3.5K -rw------- 1 root root 3.5K Jan 18 00:07 special_tokens_map.json
# 1.0K -rw------- 1 root root  570 Jan 18 00:07 tokenizer_config.json

# %% [markdown]
# # 6. Using the model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import NllbTokenizer, AutoModelForSeq2SeqLM, AutoConfig
from tqdm.auto import tqdm, trange

# %%
trans_df = pd.read_csv('/gd/MyDrive/fra_fuf_all.tsv', sep="\t")
trans_df.dropna(subset=['fra', 'fuf'], inplace=True)
df_train, df_devtest = train_test_split(trans_df, test_size=200, random_state=1)
df_dev, df_test = train_test_split(df_devtest, test_size=0.5, random_state=1)

# %%
# this code is adapted from  the Stopes repo of the NLLB team
# https://github.com/facebookresearch/stopes/blob/main/stopes/pipelines/monolingual/monolingual_line_processor.py#L214

import re
import sys
import typing as tp
import unicodedata
from sacremoses import MosesPunctNormalizer


mpn = MosesPunctNormalizer(lang="en")
mpn.substitutions = [
    (re.compile(r), sub) for r, sub in mpn.substitutions
]


def get_non_printing_char_replacer(replace_by: str = " ") -> tp.Callable[[str], str]:
    non_printable_map = {
        ord(c): replace_by
        for c in (chr(i) for i in range(sys.maxunicode + 1))
        # same as \p{C} in perl
        # see https://www.unicode.org/reports/tr44/#General_Category_Values
        if unicodedata.category(c) in {"C", "Cc", "Cf", "Cs", "Co", "Cn"}
    }

    def replace_non_printing_char(line) -> str:
        return line.translate(non_printable_map)

    return replace_non_printing_char

replace_nonprint = get_non_printing_char_replacer(" ")

def preproc(text):
    clean = mpn.normalize(text)
    clean = replace_nonprint(clean)
    # replace 𝓕𝔯𝔞𝔫𝔠𝔢𝔰𝔠𝔞 by Francesca
    clean = unicodedata.normalize("NFKC", clean)
    return clean

# %%
def fix_tokenizer(tokenizer, new_lang='fuf_Latn'):
    """ Add a new language token to the tokenizer vocabulary (this should be done each time after its initialization) """
    old_len = len(tokenizer) - int(new_lang in tokenizer.added_tokens_encoder)
    tokenizer.lang_code_to_id[new_lang] = old_len-1
    tokenizer.id_to_lang_code[old_len-1] = new_lang
    # always move "mask" to the last position
    tokenizer.fairseq_tokens_to_ids["<mask>"] = len(tokenizer.sp_model) + len(tokenizer.lang_code_to_id) + tokenizer.fairseq_offset

    tokenizer.fairseq_tokens_to_ids.update(tokenizer.lang_code_to_id)
    tokenizer.fairseq_ids_to_tokens = {v: k for k, v in tokenizer.fairseq_tokens_to_ids.items()}
    if new_lang not in tokenizer._additional_special_tokens:
        tokenizer._additional_special_tokens.append(new_lang)
    # clear the added token encoder; otherwise a new token may end up there by mistake
    tokenizer.added_tokens_encoder = {}
    tokenizer.added_tokens_decoder = {}

# %%
model_load_name = '/gd/MyDrive/models/nllb-fra-fuf-v1'
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name).cuda()
tokenizer = NllbTokenizer.from_pretrained(model_load_name)
fix_tokenizer(tokenizer)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def translate(text, src_lang='fra_Latn', tgt_lang='fuf_Latn', a=32, b=3, max_input_length=1024, num_beams=4, **kwargs):
    tokenizer.src_lang = src_lang
    tokenizer.tgt_lang = tgt_lang
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_input_length)
    result = model.generate(
        **inputs.to(model.device),
        forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang),
        max_new_tokens=int(a + b * inputs.input_ids.shape[1]),
        num_beams=num_beams,
        **kwargs
    )
    return tokenizer.batch_decode(result, skip_special_tokens=True)

# %%
t = "Où est la vache ?"
print(translate(t, 'fra_Latn', 'fuf_Latn'))
# ['Ko honɗum baali ɗin woni?']
# Out:
# ['Ko honɗum baali ɗin woni?']

# %%
translate(t, 'fra_Latn', 'fuf_Latn', do_sample=True, num_beams=1, temperature=1.5)
# Out:
# ['E ko ndi mawdi woni?']

# %%
def batched_translate(texts, batch_size=16, **kwargs):
    """Translate texts in batches of similar length"""
    idxs, texts2 = zip(*sorted(enumerate(texts), key=lambda p: len(p[1]), reverse=True))
    results = []
    for i in trange(0, len(texts2), batch_size):
        results.extend(translate(texts2[i: i+batch_size], **kwargs))
    return [p for i, p in sorted(zip(idxs, results))]

# %%
fuf_translated = batched_translate(df_dev.fra, src_lang='fra_Latn', tgt_lang='fuf_Latn')
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
df_dev['fuf_translated'] = [translate(t, 'fra_Latn', 'fuf_Latn')[0] for t in tqdm(df_dev.fra)]
df_dev['fra_translated'] = [translate(t, 'fuf_Latn', 'fra_Latn')[0] for t in tqdm(df_dev.fuf)]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
import sacrebleu
bleu_calc = sacrebleu.BLEU()
chrf_calc = sacrebleu.CHRF(word_order=2)  # this metric is called ChrF++

# %%
xx, yy = ['Bonjour'], ['Tanaala']
print(bleu_calc.corpus_score(xx, [yy]))
print(chrf_calc.corpus_score(xx, [yy]))
print(chrf_calc.corpus_score(yy, [xx]))
# Out:
# BLEU = 0.00 0.0/0.0/0.0/0.0 (BP = 1.000 ratio = 1.000 hyp_len = 2 ref_len = 2)
# chrF2++ = 36.75
# chrF2++ = 42.30

# %%
print(bleu_calc.corpus_score(df_dev['fuf_translated'].tolist(), [df_dev['fuf'].tolist()]))
print(chrf_calc.corpus_score(df_dev['fuf_translated'].tolist(), [df_dev['fuf'].tolist()]))
print(bleu_calc.corpus_score(df_dev['fra_translated'].tolist(), [df_dev['fra'].tolist()]))
print(chrf_calc.corpus_score(df_dev['fra_translated'].tolist(), [df_dev['fra'].tolist()]))
# Out:
# BLEU = 2.93 12.4/3.2/1.7/1.1 (BP = 1.000 ratio = 1.784 hyp_len = 2953 ref_len = 1655)
# chrF2++ = 15.91
# BLEU = 3.97 14.8/4.6/2.4/1.5 (BP = 1.000 ratio = 1.760 hyp_len = 3074 ref_len = 1747)
# chrF2++ = 20.39

# %%
pd.options.display.max_colwidth = 100

# %%
df_dev.sample(10, random_state=5)[['fra', 'fuf', 'fra_translated', 'fuf_translated']]
# Out:
#                                                                                                        fra  \
# 6468   Alors Jésus lui dit : « Va derrière moi , Satan ! Car il est écrit : « Tu adoreras le Seigneur t...
# 14687                                                                                              agileté
# 16919                                                                                                gomme
# 20242                                                                                    endurcir le corps
# 5607      En vérité notre Seigneur - que Sa grandeur soit exaltée - ne S'est donné ni compagne, ni enfant!
# 15737                                                                                               copeau
# 3018   Dis: «L'a fait descendre Celui qui connaît les secrets dans les cieux et la terre. Et Il est Par...
# 6054                                                             Car il était tout joyeux parmi les siens,
# 15048                                                                                               banque
# 13315  ( car ils ont été établis prêtres sans serment ) , mais il a été établi prêtre avec serment par ...
#
#                                                                                                        fuf  \
# 6468     On mo karhu-maa kadi rondanagol mo dongal , naɓaa yeru sagara gooto , naɓan mo yeru sagara ɗiɗi .
# 14687                                                                                          lontondiral
# 16919                                                                                              uumugol
# 20242                                                     Ko fawñere fii laamu addi hawre hakkunde maɓɓe .
# 5607                                                                    Accidam e mo Mi tagi on kañun tun.
# 15737                                                                                              kuruyee
# 3018   Maaɗum werlee e makko ngalu, maaɗum laatanoo mo ngesa o ñaama e mabba. Tooñooɓe ɓen wi'i: "On jo...
# 6054                                                                         O watti ngol yoorko wayliiko;
# 15048                                                                                             beereeru
# 13315  Himo wi'i taho : « A yiɗaali e a weltoraali sadakaaji e dokke e sadakaaji sunneteeɗi e sadakaaji...
#
#                                                                                             fra_translated  \
# 6468   Il répondit: " Seigneur, je te le dis en vérité, je te le dis en vérité, je te le dis en vérité,...
# 14687                                                                                             s'enfuir
# 16919                                                                                             s'enfuir
# 20242  Il s'approcha de lui et lui dit: " Lève-toi et marche! " Il lui dit: " Lève-toi et marche! " Il ...
# 5607   Il n'y a point de divinité à part Lui. Il n'y a point de divinité à part Lui. Il n'y a point de ...
# 15737                                                                                             s'enfuir
# 3018                               Il dit: "O mon peuple, je ne suis qu'un avertisseur et un avertisseur."
# 6054   Il dit: "O mon Seigneur, je ne suis qu'un avertisseur." Il dit: "O mon Seigneur, je ne suis qu'u...
# 15048                                                                                              biberon
# 13315  Car il n'y a pas de divinité qui ne vienne de l'homme, et qui ne vient pas de l'homme, mais qui ...
#
#                                                                                             fuf_translated
# 6468   Onsay Iisaa wi'i mo: " Ko honɗun mi wi'i? " Onsay o wi'i mo: " Ko honɗun mi wi'i? " Onsay o wi'i...
# 14687                                                                                            ɓeynguure
# 16919                                                                                              fiyaaku
# 20242                                                                                  ɓeynguure ɓeynguure
# 5607   Pellet, Joomi amen -Pellet, ko Kanko woni Ɓurɗo mawnude - O Waɗani hoore Makko hay gooto e maɓɓe...
# 15737                                                                                            ɓeynguure
# 3018   Maaku: "Ko Kanko Annduɗo suufaaɓe ka kammuuli e ka leydi jippini ɗum. Ko Kanko woni Haforoowo, H...
# 6054   O wi'i: "Ko honɗun mi wi'ata on?" O wi'i: "Ko honɗun mi wi'ata on?" O wi'i: "Ko honɗun mi wi'ata...
# 15048                         ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu-ɓeyngu
# 13315  Ko ɗun waɗi si mi wi'i on: " Ko honɗun mi wi'ata on? " Onsay mi wi'i mo: " Ko honɗun mi wi'ata o...

# %%
print((df_dev.fuf == df_dev.fuf_translated).mean())
print((df_dev.fra == df_dev.fra_translated).mean())
# Out:
# 0.0
# 0.0

# %%
# !pip install editdistance
# Out:
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (0.6.2)

# %%
import editdistance

def ed_similarity(text1, text2):
    return max(0, 1 - editdistance.eval(text1, text2) / min(len(text1), len(text2)))

print(ed_similarity('кот', 'собака'))
print(ed_similarity('кот', 'кит'))
# Out:
# 0
# 0.6666666666666667

# %%
pd.Series([ed_similarity(row.ru, row.rus_translated) for row in df_dev.itertuples()]).describe()
# Out:
# count    500.000000
# mean       0.516367
# std        0.392761
# min        0.000000
# 25%        0.116013
# 50%        0.507009
# 75%        1.000000
# max        1.000000
# dtype: float64

# %%
pd.Series([ed_similarity(row.tyv, row.tyv_translated) for row in df_dev.itertuples()]).describe()
# Out:
# count    500.000000
# mean       0.506007
# std        0.382357
# min        0.000000
# 25%        0.111111
# 50%        0.504902
# 75%        0.979730
# max        1.000000
# dtype: float64

# %%
df_dev.index.name = "row_id"

# %%
df_dev.to_csv(model_load_name + "/dev_set_translated.tsv", sep="\t")

# %% [markdown]
# Evaluating another model (with extended vocabulary)

# %%
model_load_name = '/gd/MyDrive/models/nllb-rus-tyv-v2-extvoc'

# %%
cfg = AutoConfig.from_pretrained(model_load_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name + "/pytorch_model_60k.bin", config=cfg).cuda()

# %%
tokenizer = NllbTokenizer.from_pretrained(model_load_name)
fix_tokenizer(tokenizer)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
df_dev['rus_translated2'] = [translate(t, 'tyv_Cyrl', 'rus_Cyrl')[0] for t in tqdm(df_dev.tyv)]
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
df_dev['tyv_translated2'] = [translate(t, 'rus_Cyrl', 'tyv_Cyrl')[0] for t in tqdm(df_dev.ru)]
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
print(bleu_calc.corpus_score(df_dev['rus_translated2'].tolist(), [df_dev['ru'].tolist()]))
print(chrf_calc.corpus_score(df_dev['rus_translated2'].tolist(), [df_dev['ru'].tolist()]))
print(bleu_calc.corpus_score(df_dev['tyv_translated2'].tolist(), [df_dev['tyv'].tolist()]))
print(chrf_calc.corpus_score(df_dev['tyv_translated2'].tolist(), [df_dev['tyv'].tolist()]))
# Out:
# BLEU = 25.18 52.4/31.3/20.4/13.3 (BP = 0.976 ratio = 0.976 hyp_len = 2269 ref_len = 2324)
# chrF2++ = 49.85
# BLEU = 23.22 51.6/29.4/18.3/11.6 (BP = 0.975 ratio = 0.975 hyp_len = 2312 ref_len = 2371)
# chrF2++ = 49.87

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name).cuda()

# %%
df_dev['rus_translated3'] = [translate(t, 'tyv_Cyrl', 'rus_Cyrl')[0] for t in tqdm(df_dev.tyv)]
df_dev['tyv_translated3'] = [translate(t, 'rus_Cyrl', 'tyv_Cyrl')[0] for t in tqdm(df_dev.ru)]
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
print(bleu_calc.corpus_score(df_dev['rus_translated3'].tolist(), [df_dev['ru'].tolist()]))
print(chrf_calc.corpus_score(df_dev['rus_translated3'].tolist(), [df_dev['ru'].tolist()]))
print(bleu_calc.corpus_score(df_dev['tyv_translated3'].tolist(), [df_dev['tyv'].tolist()]))
print(chrf_calc.corpus_score(df_dev['tyv_translated3'].tolist(), [df_dev['tyv'].tolist()]))
# Out:
# BLEU = 23.06 51.1/29.1/18.1/11.5 (BP = 0.978 ratio = 0.978 hyp_len = 2273 ref_len = 2324)
# chrF2++ = 48.56
# BLEU = 26.12 53.4/32.5/21.0/13.6 (BP = 0.985 ratio = 0.985 hyp_len = 2336 ref_len = 2371)
# chrF2++ = 52.60

# %%
df_dev['rus2eng'] = [translate(t, 'tyv_Cyrl', 'eng_Latn')[0] for t in tqdm(df_dev.tyv)]
df_dev['tyv2eng'] = [translate(t, 'rus_Cyrl', 'eng_Latn')[0] for t in tqdm(df_dev.ru)]
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]

# %% [markdown]
# Results with num_beams=1:
# ```
# V1
# BLEU = 23.21 51.2/29.1/18.0/11.8 (BP = 0.978 ratio = 0.978 hyp_len = 2273 ref_len = 2324)
# chrF2++ = 47.88
# BLEU = 22.03 51.5/29.7/17.9/10.4 (BP = 0.952 ratio = 0.953 hyp_len = 2260 ref_len = 2371)
# chrF2++ = 49.37
# V2
# BLEU = 24.08 50.9/29.5/19.1/12.3 (BP = 0.988 ratio = 0.988 hyp_len = 2297 ref_len = 2324)
# chrF2++ = 48.96
# BLEU = 22.50 50.5/28.5/17.7/11.1 (BP = 0.974 ratio = 0.974 hyp_len = 2310 ref_len = 2371)
# chrF2++ = 48.85
# V3
# BLEU = 22.25 49.8/27.8/17.2/11.0 (BP = 0.983 ratio = 0.983 hyp_len = 2284 ref_len = 2324)
# chrF2++ = 47.89
# BLEU = 25.28 52.2/31.2/20.0/13.1 (BP = 0.989 ratio = 0.989 hyp_len = 2346 ref_len = 2371)
# chrF2++ = 51.87
# ````
#
# Results with 4 beams:
# ```
# V1
# BLEU = 24.14 52.5/30.4/18.9/12.1 (BP = 0.981 ratio = 0.981 hyp_len = 2281 ref_len = 2324)
# chrF2++ = 49.49
# BLEU = 23.41 52.1/31.0/18.9/11.3 (BP = 0.966 ratio = 0.967 hyp_len = 2292 ref_len = 2371)
# chrF2++ = 50.89
# V2
# BLEU = 25.18 52.4/31.3/20.4/13.3 (BP = 0.976 ratio = 0.976 hyp_len = 2269 ref_len = 2324)
# chrF2++ = 49.85
# BLEU = 23.22 51.6/29.4/18.3/11.6 (BP = 0.975 ratio = 0.975 hyp_len = 2312 ref_len = 2371)
# chrF2++ = 49.87
# V3
# BLEU = 23.06 51.1/29.1/18.1/11.5 (BP = 0.978 ratio = 0.978 hyp_len = 2273 ref_len = 2324)
# chrF2++ = 48.56
# BLEU = 26.12 53.4/32.5/21.0/13.6 (BP = 0.985 ratio = 0.985 hyp_len = 2336 ref_len = 2371)
# chrF2++ = 52.60
# ```
#
# Which means:
# * For all directions and models, beam search improves the results
# * Longer training builds up quality for Tyvan, but decreases it for Russian.

# %% [markdown]
# ```
#                                   | tyv->rus | rus->tyv
# Model v1 (no vocabulary update):  |
#     no beam search                |   23.21  |  22.03
#     num_beams = 4                 |   24.14  |  23.41
# Model v2 (with vocabulary update):|
#     no beam search                |   24.08  |  22.50
#     num_beams = 4                 |   25.18  |  23.22
# ```

# %%
df_dev.to_csv(model_load_name + "/dev_set_translated.tsv", sep="\t")

# %% [markdown]
# Here are some examples of how translation has changed:

# %%
df_dev.sample(5, random_state=1)[['tyv', 'ru', 'rus_translated']]
# Out:
#                                                                                           tyv  \
# row_id
# 5442    транспорт херекселдерин ажыглаарының база шимчээшкинниң айыыл чок чоруунуң дүрүмнери
# 57777                                                                           аъш-чем садыы
# 104130                                                             Бүгү чүве төнген, бойлаан.
# 49344                                                                          фокуска кирбес
# 28319                                                                         рекорд тургузар
#
#                                                                         ru  \
# row_id
# 5442     правила безопасности движения и эксплуатации транспортных средств
# 57777                                            продовольственный магазин
# 104130                                         Все было кончено, потеряно.
# 49344                                                   не попасть в фокус
# 28319                                                    установить рекорд
#
#                                                            rus_translated
# row_id
# 5442    правила безопасности движения и эксплуатации транспортных средств
# 57777                                           продовольственный магазин
# 104130                                  Все было кончено, самостоятельно.
# 49344                                                  не попасть в фокус
# 28319                                                    поставить рекорд

# %%
df_dev.sample(20, random_state=1)[[
    'tyv', 'tyv_translated', 'tyv_translated2', 'tyv_translated3', 'tyv2eng',
    'ru', 'rus_translated', 'rus_translated2', 'rus_translated3', 'rus2eng',
]]
# Out:
#                                                                                           tyv  \
# row_id
# 5442    транспорт херекселдерин ажыглаарының база шимчээшкинниң айыыл чок чоруунуң дүрүмнери
# 57777                                                                           аъш-чем садыы
# 104130                                                             Бүгү чүве төнген, бойлаан.
# 49344                                                                          фокуска кирбес
# 28319                                                                         рекорд тургузар
# 43534                                                                         чурукту делгээр
# 37159                                                                            ылап хөделир
# 36993                                                                  колдуктап алгаш чоруур
# 116009                                                                 Копривничко-Крижевачка
# 113178                                                                                 Лампаң
# 106939                                             Ону кым-даа томаартып чадап каан чүве-дир.
# 86499                                                                               Самбайлык
# 20503                                                       чалбыыш ыяштарны өрттендир чипкен
# 1784                                                                              бүзүредилге
# 34052                                                                          шын эвес адаар
# 83751                                                                              Калдар аът
# 68723                                                                           соора дыңнаар
# 84267                                                                           Коңга эдипкен
# 14467                                                   мен силерге кашты төлээр ужурлуг мен?
# 54719                                                                  кончуг берге байдалдар
#
#                                                                          tyv_translated  \
# row_id
# 5442    шимчээшкинниң болгаш транспорт аймаан ажыглаарының айыыл чок чоруунуң дүрүмнери
# 57777                                                                     аъш-чем садыы
# 104130                                                    Шупту чүве доозулган, читкен.
# 49344                                                        илби-шидиге алзыр арга чок
# 28319                                                                   рекорд тургузар
# 43534                                                                   чурукту делгээр
# 37159                                                                      ылап хөделир
# 36993                                            шыңганның адаанга көдүрүп алгаш чоруур
# 116009                                                           Копривничко-Крижевачка
# 113178                                                                          Лампанг
# 106939                                                 Кым-даа ону оожургадып шыдаваан.
# 86499                                                                         Самбайлык
# 20503                                                        чалбыыш ыяштарны чиртипкен
# 1784                                                                        бүзүредилге
# 34052                                                                    шын эвес адаар
# 83751                                                                      Мухортай аът
# 68723                                                                        дыңнаалаар
# 84267                                                            Коңгулуур кыңгырт дээн
# 14467                                                          силерге чеже өрелиг мен?
# 54719                                                               кончуг берге байдал
#
#                                                                          tyv_translated2  \
# row_id
# 5442    транспорт аймаан шимчээшкининиң болгаш ажыглаарының айыыл чок чоруунуң дүрүмнери
# 57777                                                                      аъш-чем садыы
# 104130                                                        Шупту чүве төнген, читкен.
# 49344                                                                     илбиге алыспас
# 28319                                                                    рекорд тургузар
# 43534                                                                      чурук делгээр
# 37159                                                                 бүзүрелдиг хөделир
# 36993                                                              колдук адаанга аппаар
# 116009                                                            Копривничко-Крижевачка
# 113178                                                                            Лампаң
# 106939                                                  Ону кым-даа оожургадып шыдаваан.
# 86499                                                                          Самбайлык
# 20503                                                            чалбыыш ыяштарны кыпкан
# 1784                                                                           бүзүрээри
# 34052                                                                     шын эвес адаар
# 83751                                                                       Дыйлагар аът
# 68723                                                                         дыңнаалаар
# 84267                                                                  Куңгур кызаш дээн
# 14467                                                      силерге чеже хире өренир мен?
# 54719                                                                     аажок кортканы
#
#                                                                                           tyv_translated3  \
# row_id
# 5442    транспорт аймаан шимчээшкининиң болгаш транспорт аймаан ажыглаарының айыыл чок чоруунуң дүрүмнери
# 57777                                                                                       аъш-чем садыы
# 104130                                                                         Бүгү чүве бойлаан, читкен.
# 49344                                                                               илби-шидиге туттурбас
# 28319                                                                                     рекорд тургузар
# 43534                                                                                     чурукту делгээр
# 37159                                                                                        ылап хөделир
# 36993                                                                              колдуктап алгаш чоруур
# 116009                                                                             Копривничко-Крижевачка
# 113178                                                                                            Лампанг
# 106939                                                                 Оглумну кым-даа оожургап шыдаваан.
# 86499                                                                                           Самбайлык
# 20503                                                                       чалбырааш ыяштарны хөме апкан
# 1784                                                                                              бүзүрел
# 34052                                                                                         соора адаар
# 83751                                                                                        Мухортая аът
# 68723                                                                                         дыңнап алыр
# 84267                                                                             Коңгурааш, кыңгырт дээн
# 14467                                                                     силерге чеже хире өртектиг мен?
# 54719                                                                                       аажок коргары
#
#                                                                     tyv2eng  \
# row_id
# 5442    ң болгаш транспорт аймаан ажыглаарының айыыл чок чоруунуң дүрүмнери
# 57777                                                                 садыы
# 104130                                                    -даа, читкен-даа.
# 49344                                                        гге күш четпес
# 28319                                                            г тургузар
# 43534                                                     ң чурукту делгээр
# 37159                                                             г хөделир
# 36993                                                             г шыгжаар
# 116009                                                       чко-Крижевачка
# 113178                                                                    ң
# 106939                                           кым-даа оожургап шыдаваан.
# 86499                                                                     ң
# 20503                                        г чалбырааш ыяштарны чиртипкен
# 1784
# 34052                                                               ң адаар
# 83751                                                                   аът
# 68723                                                               дыңнаар
# 84267                                              ң кыңгырткайны-ла берген
# 14467                                          каш хире өрелиг мен силерге?
# 54719
#
#                                                                         ru  \
# row_id
# 5442     правила безопасности движения и эксплуатации транспортных средств
# 57777                                            продовольственный магазин
# 104130                                         Все было кончено, потеряно.
# 49344                                                   не попасть в фокус
# 28319                                                    установить рекорд
# 43534                                                   выставлять картину
# 37159                                                действовать наверняка
# 36993                                                     нести под мышкой
# 116009                                              Копривничко-Крижевачка
# 113178                                                             Лампанг
# 106939                                И никто не в силах был укротить его.
# 86499                                                            Самбайлык
# 20503                                                пламя опалило деревья
# 1784                                                          доверенность
# 34052                                              неправильно произносить
# 83751                                                      Мухортая лошадь
# 68723                                                           прослушать
# 84267                                                     Звонок прозвенел
# 14467                                                сколько я вам должен?
# 54719                                                                 ужас
#
#                                                            rus_translated  \
# row_id
# 5442    правила безопасности движения и эксплуатации транспортных средств
# 57777                                           продовольственный магазин
# 104130                                  Все было кончено, самостоятельно.
# 49344                                                  не попасть в фокус
# 28319                                                    поставить рекорд
# 43534                                                  выставлять картину
# 37159                                               действовать аккуратно
# 36993                                                   нести под мышками
# 116009                                             Копривничко-Крижевачка
# 113178                                                            Лампанг
# 106939                                 И никто не мог оглянуться на него.
# 86499                                                           Самбайлык
# 20503                                                 пламясъегло деревья
# 1784                                                              доверие
# 34052                                              неправильно произнести
# 83751                                                     Верховая лошадь
# 68723                                                          ослышаться
# 84267                                                 Прикованный к конга
# 14467                                     сколько я вам должен заплатить?
# 54719                                                               ужасы
#
#                                                           rus_translated2  \
# row_id
# 5442    правила эксплуатации транспортных средств и безопасности движения
# 57777                                           продовольственный магазин
# 104130                                          Все кончилось, разошёлся.
# 49344                                               не попасться в фокусы
# 28319                                                   установить рекорд
# 43534                                                  развернуть картину
# 37159                                               действовать наверняка
# 36993                                                   носить под мышкой
# 116009                                             Копривничко-Крижевачка
# 113178                                                            Лампанг
# 106939                                Никто не мог на это остановить его.
# 86499                                                           Самбайлык
# 20503                                             пламя разъедало деревья
# 1784                                                            убеждение
# 34052                                              неправильно произнести
# 83751                                                      Верхняя лошадь
# 68723                                                          прослушать
# 84267                                                  Конга поправленный
# 14467                                               сколько я вам обязан?
# 54719                                                               ужасы
#
#                                                           rus_translated3  \
# row_id
# 5442    правила безопасности эксплуатации транспортных средств и движения
# 57777                                           продовольственный магазин
# 104130                                              Все кончено, кончено.
# 49344                                                 не попасть на фокус
# 28319                                                   установить рекорд
# 43534                                               экспонировать картину
# 37159                                               действовать наверняка
# 36993                                                    нести под мышкой
# 116009                                             Копривничко-Крижевачка
# 113178                                                            Лампанг
# 106939                                         Никто не мог его обуздать.
# 86499                                                           Самбайлык
# 20503                                                пламя выжгло деревья
# 1784                                                            заверения
# 34052                                             неправильно произносить
# 83751                                                     Рысистая лошадь
# 68723                                                          ослышаться
# 84267                                                     звонок исправил
# 14467                                       сколько я вам должен платить?
# 54719                                                      чёрные условия
#
#                                                                                                 rus2eng
# row_id
# 5442    дүрүмнер транспорт херекселдерин ажыглаарының болгаш шимчээшкинниң айыыл чок чоруунуң дугайында
# 57777                                                                                             садыы
# 104130                                                                        -ла, бүгү чүве кончилось.
# 49344                                                                                                 г
# 28319                                                                                        г тургузар
# 43534                                                                         чурукту делгередип чуруур
# 37159                                                                                         г хөделир
# 36993                                                                                      алгаш чоруур
# 116009                                                                                вничко-Крижевачка
# 113178
# 106939                                               -ла, чүге дээрге кым-даа ону таарыштырып шыдаваан.
# 86499                                                                                                 г
# 20503                                                                         г ыяштарны чиртип каапкан
# 1784
# 34052
# 83751                                                                                               аът
# 68723                                                                                           дыңнаар
# 84267                                                                                            берген
# 14467                                                       ң дээш каш хире төлээр ужурлуг мен силерге?
# 54719                                                                                ть берге байдалдар

# %%
cols = ['ind', 'tyv', 'ru']
splits = {'train': df_train[df_train.index<=49_454], 'test': df_test, 'dev': df_dev}
df_joint = []
for k, v in splits.items():
    v = v[cols].copy()
    v.index.name = "row_id"
    v['split'] = k
    df_joint.append(v)
df_joint = pd.concat(df_joint)
df_joint.shape
# Out:
# (50000, 4)

# %%
df_joint.sample(5)
# Out:
#           ind  \
# row_id
# 314       328
# 4376     4390
# 13377   13392
# 91144   97279
# 307       321
#
#                                                                                    tyv  \
# row_id
# 314                      Өг-бүле бүрүзү эвээш дээрге-ле 500-600 ивини азырап өстүрзүн.
# 4376                                                              Өрээл аяннаны берген
# 13377                                           кым-бир кижи-биле силер деп чугаалажыр
# 91144   Идээледир чемнениринде база эки чүү-даа чүве чок, ынчангаш арай эвээшти чиңер.
# 307          Оларның аразында 14 суурда 500 четпес, а 8 суурда 250 хире чурттакчы бар.
#
#                                                                    ru  split
# row_id
# 314             Пусть на каждую семью было хотя бы по 500-600 оленей.  train
# 4376                                      Комната приняла хороший вид  train
# 13377                                           быть на вы с кем-либо  train
# 91144     Ничего хорошего нет и в переедании, так что ешьте поменьше.    dev
# 307     Среди них в 14 селах менее 500, в восьми - менее 250 человек.  train

# %%
df_joint.to_csv("/gd/MyDrive/datasets/nlp/tyvan/rus_tyv_parallel_50k.tsv", sep="\t")

# %% [markdown]
# # Publishing the model to HF

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import NllbTokenizer, AutoModelForSeq2SeqLM, AutoConfig

# %%
def fix_tokenizer(tokenizer, new_lang='tyv_Cyrl'):
    """ Add a new language token to the tokenizer vocabulary (this should be done each time after its initialization) """
    old_len = len(tokenizer) - int(new_lang in tokenizer.added_tokens_encoder)
    tokenizer.lang_code_to_id[new_lang] = old_len-1
    tokenizer.id_to_lang_code[old_len-1] = new_lang
    # always move "mask" to the last position
    tokenizer.fairseq_tokens_to_ids["<mask>"] = len(tokenizer.sp_model) + len(tokenizer.lang_code_to_id) + tokenizer.fairseq_offset

    tokenizer.fairseq_tokens_to_ids.update(tokenizer.lang_code_to_id)
    tokenizer.fairseq_ids_to_tokens = {v: k for k, v in tokenizer.fairseq_tokens_to_ids.items()}
    if new_lang not in tokenizer._additional_special_tokens:
        tokenizer._additional_special_tokens.append(new_lang)
    # clear the added token encoder; otherwise a new token may end up there by mistake
    tokenizer.added_tokens_encoder = {}
    tokenizer.added_tokens_decoder = {}

# %%
model_load_name = '/gd/MyDrive/models/nllb-rus-tyv-v1'
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name)
tokenizer = NllbTokenizer.from_pretrained(model_load_name)
fix_tokenizer(tokenizer)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
upload_repo = "slone/nllb-rus-tyv-v1"
tokenizer.push_to_hub(upload_repo)
model.push_to_hub(upload_repo)
# Out:
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/slone/nllb-rus-tyv-v1/commit/e45e25aa62c8487aaa7050d804f9851ae01e353a', commit_message='Upload M2M100ForConditionalGeneration', commit_description='', oid='e45e25aa62c8487aaa7050d804f9851ae01e353a', pr_url=None, pr_revision=None, pr_num=None)

# %%
model_load_name = '/gd/MyDrive/models/nllb-rus-tyv-v2-extvoc'
tokenizer = NllbTokenizer.from_pretrained(model_load_name)
cfg = AutoConfig.from_pretrained(model_load_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_load_name + "/pytorch_model_60k.bin", config=cfg)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
upload_repo = "slone/nllb-rus-tyv-v2-extvoc"
tokenizer.push_to_hub(upload_repo)
model.push_to_hub(upload_repo)
# Out:
# sentencepiece.bpe.model:   0%|          | 0.00/5.14M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.51G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/slone/nllb-rus-tyv-v2-extvoc/commit/48e9b1269b037fe08280bfec990c189e5748bccd', commit_message='Upload M2M100ForConditionalGeneration', commit_description='', oid='48e9b1269b037fe08280bfec990c189e5748bccd', pr_url=None, pr_revision=None, pr_num=None)

# %%
print(tokenizer.convert_ids_to_tokens([256202, 256203, 256204])) # ['zul_Latn', 'tyv_Cyrl', '<mask>']
print(tokenizer.convert_tokens_to_ids(['zul_Latn', 'tyv_Cyrl', '<mask>'])) # [256202, 256203, 256204]
# this is consistent now, wow!
# Out:
# ['zul_Latn', '<mask>', 'tyv_Cyrl']
# [256202, 256204, 256203]

# %% [markdown]
# Testing that it works

# %%
MODEL_URL = 'slone/nllb-rus-tyv-v1'
model = AutoModelForSeq2SeqLM.from_pretrained(MODEL_URL)
tokenizer = NllbTokenizer.from_pretrained(MODEL_URL, force_download=True)
fix_tokenizer(tokenizer)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/898 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def translate(
    text,
    model,
    tokenizer,
    src_lang='rus_Cyrl',
    tgt_lang='tyv_Cyrl',
    max_length='auto',
    num_beams=4,
    no_repeat_ngram_size=4,
    n_out=None,
    **kwargs
):
    tokenizer.src_lang = src_lang
    encoded = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    if max_length == 'auto':
        max_length = int(32 + 2.0 * encoded.input_ids.shape[1])
    model.eval()
    generated_tokens = model.generate(
        **encoded.to(model.device),
        forced_bos_token_id=tokenizer.lang_code_to_id[tgt_lang],
        max_length=max_length,
        num_beams=num_beams,
        no_repeat_ngram_size=no_repeat_ngram_size,
        num_return_sequences=n_out or 1,
        **kwargs
    )
    out = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)
    if isinstance(text, str) and n_out is None:
        return out[0]
    return out

# %%
translate("красная птица", model=model, tokenizer=tokenizer)
# Out:
# 'кызыл куш'

# %%
translate("красная птица", model=model, tokenizer=tokenizer, tgt_lang='eng_Latn')
# Out:
# ': кызыл куш'

# %%
lang_to_code = {
    'Русский | Russian': 'rus_Cyrl',
    'Тувинский | Tyvan': 'tyv_Cyrl',
}

# %%
def translate_wrapper(text, src, trg, correct=None):
    src_lang = lang_to_code.get(src)
    tgt_lang = lang_to_code.get(trg)
    if src == trg:
        return 'Please choose two different languages'
    print(text, src, trg)
    result = translate(
        text=text,
        model=model,
        tokenizer=tokenizer,
        src_lang=src_lang,
        tgt_lang=tgt_lang,
    )
    return result

# %%
translate_wrapper("красная птица", 'Русский | Russian', 'Тувинский | Tyvan')
# Out:
# красная птица Русский | Russian Тувинский | Tyvan
# 'кызыл куш'
